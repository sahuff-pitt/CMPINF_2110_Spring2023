# %% [markdown]
# ## CMPINF 2110 Spring 2022 - Week 04
#
# ### Revisit the shoe example

# %% [markdown]
# ## Import Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# ## Read data
#
# Read in the tidied long-format shoe data set.

# %%
lf = pd.read_csv('../data/shoes_long_format.csv')

# %%
lf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   day       40 non-null     int64
#  1   shoe      40 non-null     object
#  2   value     40 non-null     int64
#  3   location  40 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 1.4+ KB

# %%
lf.head()
# Out:
#    day shoe  value location
# 0    1    W     12        N
# 1    2    W      5        N
# 2    3    W      9        N
# 3    4    W      4        N
# 4    1    B      5        N

# %% [markdown]
# We had defined the **observational unit** as the a number or count of a color of shoe entering a location on a day.
#
# As a refresher we have the following unique values.

# %%
lf.nunique()
# Out:
# day          4
# shoe         4
# value       16
# location     3
# dtype: int64

# %%
lf.location.value_counts()
# Out:
# N    16
# D    16
# P     8
# Name: location, dtype: int64

# %%
lf.shoe.value_counts()
# Out:
# W    10
# B    10
# R    10
# O    10
# Name: shoe, dtype: int64

# %%
lf.day.value_counts()
# Out:
# 2    12
# 3    12
# 1     8
# 4     8
# Name: day, dtype: int64

# %% [markdown]
# ## Add information about the locations
#
# I don't remember what D vs N vs P stands for in this example. Let's use the real names for the locations.
#
# It's easier to work with a smaller data set focused on the locations when we make this change.
#
# Essentially, let's create a DataFrame where 1 row is 1 location.

# %%
lf.groupby(['location']).nunique().reset_index()
# Out:
#   location  day  shoe  value
# 0        D    4     4      9
# 1        N    4     4     14
# 2        P    2     4      7

# %%
lf.groupby(['location']).size().reset_index(name='num_rows')
# Out:
#   location  num_rows
# 0        D        16
# 1        N        16
# 2        P         8

# %% [markdown]
# But we don't care about the number of rows at the moment, so we can drop it.

# %%
lf.groupby(['location']).size().reset_index(name='num_rows').drop(columns=['num_rows'])
# Out:
#   location
# 0        D
# 1        N
# 2        P

# %%
location_info = lf.groupby(['location']).size().reset_index(name='num_rows').drop(columns=['num_rows'])

# %%
location_info
# Out:
#   location
# 0        D
# 1        N
# 2        P

# %% [markdown]
# One row is one location and so now we can easily add information or **attributes** about each location.

# %%
location_info['location_name'] = pd.Series(['Dunkin Donuts', 
                                            'Noodles & Company',
                                            'Panera Bread'],
                                            index=location_info.index)

# %%
location_info
# Out:
#   location      location_name
# 0        D      Dunkin Donuts
# 1        N  Noodles & Company
# 2        P       Panera Bread

# %% [markdown]
# What if we wanted to know the address for each location?

# %%
location_info['address'] = pd.Series(['3907 Forbes Ave, Pittsburgh, PA 15123',
                                      '3805 Forbes Ave, Pittsburgh, PA 15123',
                                      '3800 Forbes Ave, Pittsburgh, PA 15123'],
                                     index=location_info.index)

# %%
location_info
# Out:
#   location      location_name                                address
# 0        D      Dunkin Donuts  3907 Forbes Ave, Pittsburgh, PA 15123
# 1        N  Noodles & Company  3805 Forbes Ave, Pittsburgh, PA 15123
# 2        P       Panera Bread  3800 Forbes Ave, Pittsburgh, PA 15123

# %% [markdown]
# Split or SEPARATE a string to parse out context from a big string.
#
# Let's split the address into the street, city, state, and zipcode.

# %% [markdown]
# Split or separate by the comma pattern first. Include an additional space after the comma.

# %%
location_info.address.str.split('\, ')
# Out:
# 0    [3907 Forbes Ave, Pittsburgh, PA 15123]
# 1    [3805 Forbes Ave, Pittsburgh, PA 15123]
# 2    [3800 Forbes Ave, Pittsburgh, PA 15123]
# Name: address, dtype: object

# %%
location_info.address.str.split('\, ', expand=True)
# Out:
#                  0           1         2
# 0  3907 Forbes Ave  Pittsburgh  PA 15123
# 1  3805 Forbes Ave  Pittsburgh  PA 15123
# 2  3800 Forbes Ave  Pittsburgh  PA 15123

# %%
location_info[['street_address', 'city', 'state_zip']] = location_info.address.str.split('\, ', expand=True)

# %%
location_info
# Out:
#   location      location_name                                address  \
# 0        D      Dunkin Donuts  3907 Forbes Ave, Pittsburgh, PA 15123
# 1        N  Noodles & Company  3805 Forbes Ave, Pittsburgh, PA 15123
# 2        P       Panera Bread  3800 Forbes Ave, Pittsburgh, PA 15123
#
#     street_address        city state_zip
# 0  3907 Forbes Ave  Pittsburgh  PA 15123
# 1  3805 Forbes Ave  Pittsburgh  PA 15123
# 2  3800 Forbes Ave  Pittsburgh  PA 15123

# %% [markdown]
# Separate the state and zipcode on the white space.

# %%
location_info.state_zip.str.split(' ')
# Out:
# 0    [PA, 15123]
# 1    [PA, 15123]
# 2    [PA, 15123]
# Name: state_zip, dtype: object

# %%
location_info.state_zip.str.split(' ', expand=True)
# Out:
#     0      1
# 0  PA  15123
# 1  PA  15123
# 2  PA  15123

# %%
location_info[['state', 'zipcode']] = location_info.state_zip.str.split(' ', expand=True)

# %%
location_info
# Out:
#   location      location_name                                address  \
# 0        D      Dunkin Donuts  3907 Forbes Ave, Pittsburgh, PA 15123
# 1        N  Noodles & Company  3805 Forbes Ave, Pittsburgh, PA 15123
# 2        P       Panera Bread  3800 Forbes Ave, Pittsburgh, PA 15123
#
#     street_address        city state_zip state zipcode
# 0  3907 Forbes Ave  Pittsburgh  PA 15123    PA   15123
# 1  3805 Forbes Ave  Pittsburgh  PA 15123    PA   15123
# 2  3800 Forbes Ave  Pittsburgh  PA 15123    PA   15123

# %% [markdown]
# Drop the unncessary information that we parsed by splitting the strings.

# %%
location_info.drop(columns=['address', 'state_zip'], inplace=True)

# %%
location_info
# Out:
#   location      location_name   street_address        city state zipcode
# 0        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh    PA   15123
# 1        N  Noodles & Company  3805 Forbes Ave  Pittsburgh    PA   15123
# 2        P       Panera Bread  3800 Forbes Ave  Pittsburgh    PA   15123

# %% [markdown]
# We can JOIN the more detailed information to our TIDY data!

# %%
pd.merge(lf, location_info, on='location', how='left')
# Out:
#     day shoe  value location      location_name   street_address        city  \
# 0     1    W     12        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 1     2    W      5        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 2     3    W      9        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 3     4    W      4        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 4     1    B      5        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 5     2    B      8        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 6     3    B     22        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 7     4    B      2        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 8     1    R      3        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 9     2    R      6        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 10    3    R      7        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 11    4    R      1        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 12    1    O     15        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 13    2    O     20        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 14    3    O     13        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 15    4    O      7        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 16    1    W      9        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 17    2    W      9        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 18    3    W      2        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 19    4    W      5        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 20    1    B      8        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 21    2    B      3        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 22    3    B     11        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 23    4    B      8        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 24    1    R      2        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 25    2    R      8        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 26    3    R     13        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 27    4    R      3        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 28    1    O     11        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 29    2    O     14        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 30    3    O      5        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 31    4    O     12        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 32    2    W      9        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 33    3    W      7        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 34    2    B      3        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 35    3    B      4        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 36    2    R      4        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 37    3    R      5        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 38    2    O     15        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 39    3    O     11        P       Panera Bread  3800 Forbes Ave  Pittsburgh
#
#    state zipcode
# 0     PA   15123
# 1     PA   15123
# 2     PA   15123
# 3     PA   15123
# 4     PA   15123
# 5     PA   15123
# 6     PA   15123
# 7     PA   15123
# 8     PA   15123
# 9     PA   15123
# 10    PA   15123
# 11    PA   15123
# 12    PA   15123
# 13    PA   15123
# 14    PA   15123
# 15    PA   15123
# 16    PA   15123
# 17    PA   15123
# 18    PA   15123
# 19    PA   15123
# 20    PA   15123
# 21    PA   15123
# 22    PA   15123
# 23    PA   15123
# 24    PA   15123
# 25    PA   15123
# 26    PA   15123
# 27    PA   15123
# 28    PA   15123
# 29    PA   15123
# 30    PA   15123
# 31    PA   15123
# 32    PA   15123
# 33    PA   15123
# 34    PA   15123
# 35    PA   15123
# 36    PA   15123
# 37    PA   15123
# 38    PA   15123
# 39    PA   15123

# %% [markdown]
# I used a left join...would it have been wrong here to use a RIGHT JOIN?

# %%
lf.head()
# Out:
#    day shoe  value location
# 0    1    W     12        N
# 1    2    W      5        N
# 2    3    W      9        N
# 3    4    W      4        N
# 4    1    B      5        N

# %%
lf.tail()
# Out:
#     day shoe  value location
# 35    3    B      4        P
# 36    2    R      4        P
# 37    3    R      5        P
# 38    2    O     15        P
# 39    3    O     11        P

# %%
location_info
# Out:
#   location      location_name   street_address        city state zipcode
# 0        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh    PA   15123
# 1        N  Noodles & Company  3805 Forbes Ave  Pittsburgh    PA   15123
# 2        P       Panera Bread  3800 Forbes Ave  Pittsburgh    PA   15123

# %% [markdown]
# What if we used a RIGHT JOIN instead of a LEFT JOIN?

# %%
pd.merge(lf, location_info, on='location', how='right')
# Out:
#     day shoe  value location      location_name   street_address        city  \
# 0     1    W      9        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 1     2    W      9        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 2     3    W      2        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 3     4    W      5        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 4     1    B      8        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 5     2    B      3        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 6     3    B     11        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 7     4    B      8        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 8     1    R      2        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 9     2    R      8        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 10    3    R     13        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 11    4    R      3        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 12    1    O     11        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 13    2    O     14        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 14    3    O      5        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 15    4    O     12        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 16    1    W     12        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 17    2    W      5        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 18    3    W      9        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 19    4    W      4        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 20    1    B      5        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 21    2    B      8        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 22    3    B     22        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 23    4    B      2        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 24    1    R      3        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 25    2    R      6        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 26    3    R      7        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 27    4    R      1        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 28    1    O     15        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 29    2    O     20        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 30    3    O     13        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 31    4    O      7        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 32    2    W      9        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 33    3    W      7        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 34    2    B      3        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 35    3    B      4        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 36    2    R      4        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 37    3    R      5        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 38    2    O     15        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 39    3    O     11        P       Panera Bread  3800 Forbes Ave  Pittsburgh
#
#    state zipcode
# 0     PA   15123
# 1     PA   15123
# 2     PA   15123
# 3     PA   15123
# 4     PA   15123
# 5     PA   15123
# 6     PA   15123
# 7     PA   15123
# 8     PA   15123
# 9     PA   15123
# 10    PA   15123
# 11    PA   15123
# 12    PA   15123
# 13    PA   15123
# 14    PA   15123
# 15    PA   15123
# 16    PA   15123
# 17    PA   15123
# 18    PA   15123
# 19    PA   15123
# 20    PA   15123
# 21    PA   15123
# 22    PA   15123
# 23    PA   15123
# 24    PA   15123
# 25    PA   15123
# 26    PA   15123
# 27    PA   15123
# 28    PA   15123
# 29    PA   15123
# 30    PA   15123
# 31    PA   15123
# 32    PA   15123
# 33    PA   15123
# 34    PA   15123
# 35    PA   15123
# 36    PA   15123
# 37    PA   15123
# 38    PA   15123
# 39    PA   15123

# %% [markdown]
# For this example, it does not matter whether we use a LEFT, RIGHT, INNER, or OUTER join.

# %%
pd.merge(lf, location_info, on='location', how='inner')
# Out:
#     day shoe  value location      location_name   street_address        city  \
# 0     1    W     12        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 1     2    W      5        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 2     3    W      9        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 3     4    W      4        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 4     1    B      5        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 5     2    B      8        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 6     3    B     22        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 7     4    B      2        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 8     1    R      3        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 9     2    R      6        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 10    3    R      7        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 11    4    R      1        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 12    1    O     15        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 13    2    O     20        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 14    3    O     13        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 15    4    O      7        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 16    1    W      9        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 17    2    W      9        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 18    3    W      2        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 19    4    W      5        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 20    1    B      8        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 21    2    B      3        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 22    3    B     11        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 23    4    B      8        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 24    1    R      2        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 25    2    R      8        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 26    3    R     13        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 27    4    R      3        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 28    1    O     11        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 29    2    O     14        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 30    3    O      5        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 31    4    O     12        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 32    2    W      9        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 33    3    W      7        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 34    2    B      3        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 35    3    B      4        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 36    2    R      4        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 37    3    R      5        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 38    2    O     15        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 39    3    O     11        P       Panera Bread  3800 Forbes Ave  Pittsburgh
#
#    state zipcode
# 0     PA   15123
# 1     PA   15123
# 2     PA   15123
# 3     PA   15123
# 4     PA   15123
# 5     PA   15123
# 6     PA   15123
# 7     PA   15123
# 8     PA   15123
# 9     PA   15123
# 10    PA   15123
# 11    PA   15123
# 12    PA   15123
# 13    PA   15123
# 14    PA   15123
# 15    PA   15123
# 16    PA   15123
# 17    PA   15123
# 18    PA   15123
# 19    PA   15123
# 20    PA   15123
# 21    PA   15123
# 22    PA   15123
# 23    PA   15123
# 24    PA   15123
# 25    PA   15123
# 26    PA   15123
# 27    PA   15123
# 28    PA   15123
# 29    PA   15123
# 30    PA   15123
# 31    PA   15123
# 32    PA   15123
# 33    PA   15123
# 34    PA   15123
# 35    PA   15123
# 36    PA   15123
# 37    PA   15123
# 38    PA   15123
# 39    PA   15123

# %%
pd.merge(lf, location_info, on='location', how='outer')
# Out:
#     day shoe  value location      location_name   street_address        city  \
# 0     1    W     12        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 1     2    W      5        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 2     3    W      9        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 3     4    W      4        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 4     1    B      5        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 5     2    B      8        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 6     3    B     22        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 7     4    B      2        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 8     1    R      3        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 9     2    R      6        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 10    3    R      7        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 11    4    R      1        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 12    1    O     15        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 13    2    O     20        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 14    3    O     13        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 15    4    O      7        N  Noodles & Company  3805 Forbes Ave  Pittsburgh
# 16    1    W      9        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 17    2    W      9        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 18    3    W      2        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 19    4    W      5        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 20    1    B      8        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 21    2    B      3        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 22    3    B     11        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 23    4    B      8        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 24    1    R      2        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 25    2    R      8        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 26    3    R     13        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 27    4    R      3        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 28    1    O     11        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 29    2    O     14        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 30    3    O      5        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 31    4    O     12        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh
# 32    2    W      9        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 33    3    W      7        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 34    2    B      3        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 35    3    B      4        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 36    2    R      4        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 37    3    R      5        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 38    2    O     15        P       Panera Bread  3800 Forbes Ave  Pittsburgh
# 39    3    O     11        P       Panera Bread  3800 Forbes Ave  Pittsburgh
#
#    state zipcode
# 0     PA   15123
# 1     PA   15123
# 2     PA   15123
# 3     PA   15123
# 4     PA   15123
# 5     PA   15123
# 6     PA   15123
# 7     PA   15123
# 8     PA   15123
# 9     PA   15123
# 10    PA   15123
# 11    PA   15123
# 12    PA   15123
# 13    PA   15123
# 14    PA   15123
# 15    PA   15123
# 16    PA   15123
# 17    PA   15123
# 18    PA   15123
# 19    PA   15123
# 20    PA   15123
# 21    PA   15123
# 22    PA   15123
# 23    PA   15123
# 24    PA   15123
# 25    PA   15123
# 26    PA   15123
# 27    PA   15123
# 28    PA   15123
# 29    PA   15123
# 30    PA   15123
# 31    PA   15123
# 32    PA   15123
# 33    PA   15123
# 34    PA   15123
# 35    PA   15123
# 36    PA   15123
# 37    PA   15123
# 38    PA   15123
# 39    PA   15123

# %% [markdown]
# ## Identify the unique shoes and add context

# %%
lf.head()
# Out:
#    day shoe  value location
# 0    1    W     12        N
# 1    2    W      5        N
# 2    3    W      9        N
# 3    4    W      4        N
# 4    1    B      5        N

# %%
lf.shoe.value_counts()
# Out:
# W    10
# B    10
# R    10
# O    10
# Name: shoe, dtype: int64

# %%
shoe_info = lf.groupby(['shoe']).size().reset_index(name='num_rows').drop(columns=['num_rows'])

# %%
shoe_info
# Out:
#   shoe
# 0    B
# 1    O
# 2    R
# 3    W

# %%
shoe_info['shoe_color'] = pd.Series(['Black', 'Other', 'Red', 'White'],
                                    index=shoe_info.index)

# %%
shoe_info
# Out:
#   shoe shoe_color
# 0    B      Black
# 1    O      Other
# 2    R        Red
# 3    W      White

# %% [markdown]
# We can merge all 3 data sets together in a single line of code by CHAINING the JOINS.
#
# Pay close attention to the **on** variable with the JOINS.

# %%
pd.merge(lf, shoe_info, on='shoe', how='left').\
merge(location_info, on='location', how='left')
# Out:
#     day shoe  value location shoe_color      location_name   street_address  \
# 0     1    W     12        N      White  Noodles & Company  3805 Forbes Ave
# 1     2    W      5        N      White  Noodles & Company  3805 Forbes Ave
# 2     3    W      9        N      White  Noodles & Company  3805 Forbes Ave
# 3     4    W      4        N      White  Noodles & Company  3805 Forbes Ave
# 4     1    B      5        N      Black  Noodles & Company  3805 Forbes Ave
# 5     2    B      8        N      Black  Noodles & Company  3805 Forbes Ave
# 6     3    B     22        N      Black  Noodles & Company  3805 Forbes Ave
# 7     4    B      2        N      Black  Noodles & Company  3805 Forbes Ave
# 8     1    R      3        N        Red  Noodles & Company  3805 Forbes Ave
# 9     2    R      6        N        Red  Noodles & Company  3805 Forbes Ave
# 10    3    R      7        N        Red  Noodles & Company  3805 Forbes Ave
# 11    4    R      1        N        Red  Noodles & Company  3805 Forbes Ave
# 12    1    O     15        N      Other  Noodles & Company  3805 Forbes Ave
# 13    2    O     20        N      Other  Noodles & Company  3805 Forbes Ave
# 14    3    O     13        N      Other  Noodles & Company  3805 Forbes Ave
# 15    4    O      7        N      Other  Noodles & Company  3805 Forbes Ave
# 16    1    W      9        D      White      Dunkin Donuts  3907 Forbes Ave
# 17    2    W      9        D      White      Dunkin Donuts  3907 Forbes Ave
# 18    3    W      2        D      White      Dunkin Donuts  3907 Forbes Ave
# 19    4    W      5        D      White      Dunkin Donuts  3907 Forbes Ave
# 20    1    B      8        D      Black      Dunkin Donuts  3907 Forbes Ave
# 21    2    B      3        D      Black      Dunkin Donuts  3907 Forbes Ave
# 22    3    B     11        D      Black      Dunkin Donuts  3907 Forbes Ave
# 23    4    B      8        D      Black      Dunkin Donuts  3907 Forbes Ave
# 24    1    R      2        D        Red      Dunkin Donuts  3907 Forbes Ave
# 25    2    R      8        D        Red      Dunkin Donuts  3907 Forbes Ave
# 26    3    R     13        D        Red      Dunkin Donuts  3907 Forbes Ave
# 27    4    R      3        D        Red      Dunkin Donuts  3907 Forbes Ave
# 28    1    O     11        D      Other      Dunkin Donuts  3907 Forbes Ave
# 29    2    O     14        D      Other      Dunkin Donuts  3907 Forbes Ave
# 30    3    O      5        D      Other      Dunkin Donuts  3907 Forbes Ave
# 31    4    O     12        D      Other      Dunkin Donuts  3907 Forbes Ave
# 32    2    W      9        P      White       Panera Bread  3800 Forbes Ave
# 33    3    W      7        P      White       Panera Bread  3800 Forbes Ave
# 34    2    B      3        P      Black       Panera Bread  3800 Forbes Ave
# 35    3    B      4        P      Black       Panera Bread  3800 Forbes Ave
# 36    2    R      4        P        Red       Panera Bread  3800 Forbes Ave
# 37    3    R      5        P        Red       Panera Bread  3800 Forbes Ave
# 38    2    O     15        P      Other       Panera Bread  3800 Forbes Ave
# 39    3    O     11        P      Other       Panera Bread  3800 Forbes Ave
#
#           city state zipcode
# 0   Pittsburgh    PA   15123
# 1   Pittsburgh    PA   15123
# 2   Pittsburgh    PA   15123
# 3   Pittsburgh    PA   15123
# 4   Pittsburgh    PA   15123
# 5   Pittsburgh    PA   15123
# 6   Pittsburgh    PA   15123
# 7   Pittsburgh    PA   15123
# 8   Pittsburgh    PA   15123
# 9   Pittsburgh    PA   15123
# 10  Pittsburgh    PA   15123
# 11  Pittsburgh    PA   15123
# 12  Pittsburgh    PA   15123
# 13  Pittsburgh    PA   15123
# 14  Pittsburgh    PA   15123
# 15  Pittsburgh    PA   15123
# 16  Pittsburgh    PA   15123
# 17  Pittsburgh    PA   15123
# 18  Pittsburgh    PA   15123
# 19  Pittsburgh    PA   15123
# 20  Pittsburgh    PA   15123
# 21  Pittsburgh    PA   15123
# 22  Pittsburgh    PA   15123
# 23  Pittsburgh    PA   15123
# 24  Pittsburgh    PA   15123
# 25  Pittsburgh    PA   15123
# 26  Pittsburgh    PA   15123
# 27  Pittsburgh    PA   15123
# 28  Pittsburgh    PA   15123
# 29  Pittsburgh    PA   15123
# 30  Pittsburgh    PA   15123
# 31  Pittsburgh    PA   15123
# 32  Pittsburgh    PA   15123
# 33  Pittsburgh    PA   15123
# 34  Pittsburgh    PA   15123
# 35  Pittsburgh    PA   15123
# 36  Pittsburgh    PA   15123
# 37  Pittsburgh    PA   15123
# 38  Pittsburgh    PA   15123
# 39  Pittsburgh    PA   15123

# %% [markdown]
# ## Integer identifers

# %%
location_info
# Out:
#   location      location_name   street_address        city state zipcode
# 0        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh    PA   15123
# 1        N  Noodles & Company  3805 Forbes Ave  Pittsburgh    PA   15123
# 2        P       Panera Bread  3800 Forbes Ave  Pittsburgh    PA   15123

# %%
shoe_info
# Out:
#   shoe shoe_color
# 0    B      Black
# 1    O      Other
# 2    R        Red
# 3    W      White

# %% [markdown]
# We will see why in a little bit having each row in the smaller more refined tables be identified by an integer.

# %%
location_info['location_id'] = location_info.index + 1

# %%
location_info
# Out:
#   location      location_name   street_address        city state zipcode  \
# 0        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh    PA   15123
# 1        N  Noodles & Company  3805 Forbes Ave  Pittsburgh    PA   15123
# 2        P       Panera Bread  3800 Forbes Ave  Pittsburgh    PA   15123
#
#    location_id
# 0            1
# 1            2
# 2            3

# %%
shoe_info['shoe_id'] = shoe_info.index + 1

# %%
shoe_info
# Out:
#   shoe shoe_color  shoe_id
# 0    B      Black        1
# 1    O      Other        2
# 2    R        Red        3
# 3    W      White        4

# %% [markdown]
# Merge the unique integer identifiers into the TIDY data set.

# %%
lf_copy = pd.merge(lf, shoe_info.loc[:, ['shoe_id', 'shoe']], on='shoe', how='left').\
merge(location_info.loc[:, ['location_id', 'location']], on='location', how='left')

# %%
lf_copy.head()
# Out:
#    day shoe  value location  shoe_id  location_id
# 0    1    W     12        N        4            2
# 1    2    W      5        N        4            2
# 2    3    W      9        N        4            2
# 3    4    W      4        N        4            2
# 4    1    B      5        N        1            2

# %%
lf_copy.tail()
# Out:
#     day shoe  value location  shoe_id  location_id
# 35    3    B      4        P        1            3
# 36    2    R      4        P        3            3
# 37    3    R      5        P        3            3
# 38    2    O     15        P        2            3
# 39    3    O     11        P        2            3

# %% [markdown]
# We can drop the original `shoe` and `location` columns.

# %%
lf_copy.drop(columns=['shoe', 'location'], inplace=True)

# %%
lf_copy.head()
# Out:
#    day  value  shoe_id  location_id
# 0    1     12        4            2
# 1    2      5        4            2
# 2    3      9        4            2
# 3    4      4        4            2
# 4    1      5        1            2

# %%
lf_copy = lf_copy[['day', 'location_id', 'shoe_id', 'value']].copy()

# %%
lf_copy.head()
# Out:
#    day  location_id  shoe_id  value
# 0    1            2        4     12
# 1    2            2        4      5
# 2    3            2        4      9
# 3    4            2        4      4
# 4    1            2        1      5

# %% [markdown]
# We can always recover the TIDY analytics ready data by JOINING the 3 data sets together!

# %%
pd.merge(lf_copy, shoe_info, on='shoe_id', how='left').\
merge(location_info, on='location_id', how='left')
# Out:
#     day  location_id  shoe_id  value shoe shoe_color location  \
# 0     1            2        4     12    W      White        N
# 1     2            2        4      5    W      White        N
# 2     3            2        4      9    W      White        N
# 3     4            2        4      4    W      White        N
# 4     1            2        1      5    B      Black        N
# 5     2            2        1      8    B      Black        N
# 6     3            2        1     22    B      Black        N
# 7     4            2        1      2    B      Black        N
# 8     1            2        3      3    R        Red        N
# 9     2            2        3      6    R        Red        N
# 10    3            2        3      7    R        Red        N
# 11    4            2        3      1    R        Red        N
# 12    1            2        2     15    O      Other        N
# 13    2            2        2     20    O      Other        N
# 14    3            2        2     13    O      Other        N
# 15    4            2        2      7    O      Other        N
# 16    1            1        4      9    W      White        D
# 17    2            1        4      9    W      White        D
# 18    3            1        4      2    W      White        D
# 19    4            1        4      5    W      White        D
# 20    1            1        1      8    B      Black        D
# 21    2            1        1      3    B      Black        D
# 22    3            1        1     11    B      Black        D
# 23    4            1        1      8    B      Black        D
# 24    1            1        3      2    R        Red        D
# 25    2            1        3      8    R        Red        D
# 26    3            1        3     13    R        Red        D
# 27    4            1        3      3    R        Red        D
# 28    1            1        2     11    O      Other        D
# 29    2            1        2     14    O      Other        D
# 30    3            1        2      5    O      Other        D
# 31    4            1        2     12    O      Other        D
# 32    2            3        4      9    W      White        P
# 33    3            3        4      7    W      White        P
# 34    2            3        1      3    B      Black        P
# 35    3            3        1      4    B      Black        P
# 36    2            3        3      4    R        Red        P
# 37    3            3        3      5    R        Red        P
# 38    2            3        2     15    O      Other        P
# 39    3            3        2     11    O      Other        P
#
#         location_name   street_address        city state zipcode
# 0   Noodles & Company  3805 Forbes Ave  Pittsburgh    PA   15123
# 1   Noodles & Company  3805 Forbes Ave  Pittsburgh    PA   15123
# 2   Noodles & Company  3805 Forbes Ave  Pittsburgh    PA   15123
# 3   Noodles & Company  3805 Forbes Ave  Pittsburgh    PA   15123
# 4   Noodles & Company  3805 Forbes Ave  Pittsburgh    PA   15123
# 5   Noodles & Company  3805 Forbes Ave  Pittsburgh    PA   15123
# 6   Noodles & Company  3805 Forbes Ave  Pittsburgh    PA   15123
# 7   Noodles & Company  3805 Forbes Ave  Pittsburgh    PA   15123
# 8   Noodles & Company  3805 Forbes Ave  Pittsburgh    PA   15123
# 9   Noodles & Company  3805 Forbes Ave  Pittsburgh    PA   15123
# 10  Noodles & Company  3805 Forbes Ave  Pittsburgh    PA   15123
# 11  Noodles & Company  3805 Forbes Ave  Pittsburgh    PA   15123
# 12  Noodles & Company  3805 Forbes Ave  Pittsburgh    PA   15123
# 13  Noodles & Company  3805 Forbes Ave  Pittsburgh    PA   15123
# 14  Noodles & Company  3805 Forbes Ave  Pittsburgh    PA   15123
# 15  Noodles & Company  3805 Forbes Ave  Pittsburgh    PA   15123
# 16      Dunkin Donuts  3907 Forbes Ave  Pittsburgh    PA   15123
# 17      Dunkin Donuts  3907 Forbes Ave  Pittsburgh    PA   15123
# 18      Dunkin Donuts  3907 Forbes Ave  Pittsburgh    PA   15123
# 19      Dunkin Donuts  3907 Forbes Ave  Pittsburgh    PA   15123
# 20      Dunkin Donuts  3907 Forbes Ave  Pittsburgh    PA   15123
# 21      Dunkin Donuts  3907 Forbes Ave  Pittsburgh    PA   15123
# 22      Dunkin Donuts  3907 Forbes Ave  Pittsburgh    PA   15123
# 23      Dunkin Donuts  3907 Forbes Ave  Pittsburgh    PA   15123
# 24      Dunkin Donuts  3907 Forbes Ave  Pittsburgh    PA   15123
# 25      Dunkin Donuts  3907 Forbes Ave  Pittsburgh    PA   15123
# 26      Dunkin Donuts  3907 Forbes Ave  Pittsburgh    PA   15123
# 27      Dunkin Donuts  3907 Forbes Ave  Pittsburgh    PA   15123
# 28      Dunkin Donuts  3907 Forbes Ave  Pittsburgh    PA   15123
# 29      Dunkin Donuts  3907 Forbes Ave  Pittsburgh    PA   15123
# 30      Dunkin Donuts  3907 Forbes Ave  Pittsburgh    PA   15123
# 31      Dunkin Donuts  3907 Forbes Ave  Pittsburgh    PA   15123
# 32       Panera Bread  3800 Forbes Ave  Pittsburgh    PA   15123
# 33       Panera Bread  3800 Forbes Ave  Pittsburgh    PA   15123
# 34       Panera Bread  3800 Forbes Ave  Pittsburgh    PA   15123
# 35       Panera Bread  3800 Forbes Ave  Pittsburgh    PA   15123
# 36       Panera Bread  3800 Forbes Ave  Pittsburgh    PA   15123
# 37       Panera Bread  3800 Forbes Ave  Pittsburgh    PA   15123
# 38       Panera Bread  3800 Forbes Ave  Pittsburgh    PA   15123
# 39       Panera Bread  3800 Forbes Ave  Pittsburgh    PA   15123

# %%
lf_copy.head()
# Out:
#    day  location_id  shoe_id  value
# 0    1            2        4     12
# 1    2            2        4      5
# 2    3            2        4      9
# 3    4            2        4      4
# 4    1            2        1      5

# %% [markdown]
# Add in a unique integer row identifier to the **link** table.

# %%
shoe_per_day = lf_copy.copy()

# %%
shoe_per_day['id'] = shoe_per_day.index + 1

# %%
shoe_per_day.head()
# Out:
#    day  location_id  shoe_id  value  id
# 0    1            2        4     12   1
# 1    2            2        4      5   2
# 2    3            2        4      9   3
# 3    4            2        4      4   4
# 4    1            2        1      5   5

# %%
shoe_per_day.tail()
# Out:
#     day  location_id  shoe_id  value  id
# 35    3            3        1      4  36
# 36    2            3        3      4  37
# 37    3            3        3      5  38
# 38    2            3        2     15  39
# 39    3            3        2     11  40

# %% [markdown]
# Rearrange the columns.

# %%
['id'] + lf_copy.columns.to_list()
# Out:
# ['id', 'day', 'location_id', 'shoe_id', 'value']

# %%
shoe_per_day = shoe_per_day[['id'] + lf_copy.columns.to_list()].copy()

# %%
shoe_per_day.head()
# Out:
#    id  day  location_id  shoe_id  value
# 0   1    1            2        4     12
# 1   2    2            2        4      5
# 2   3    3            2        4      9
# 3   4    4            2        4      4
# 4   5    1            2        1      5

# %% [markdown]
# Rearrange the columns for the shoe and location DataFrames as well.

# %%
shoe_info
# Out:
#   shoe shoe_color  shoe_id
# 0    B      Black        1
# 1    O      Other        2
# 2    R        Red        3
# 3    W      White        4

# %%
['shoe_id'] + shoe_info.columns.to_list()[:-1]
# Out:
# ['shoe_id', 'shoe', 'shoe_color']

# %%
shoe_info = shoe_info[['shoe_id'] + shoe_info.columns.to_list()[:-1]].copy()

# %%
shoe_info
# Out:
#    shoe_id shoe shoe_color
# 0        1    B      Black
# 1        2    O      Other
# 2        3    R        Red
# 3        4    W      White

# %%
location_info
# Out:
#   location      location_name   street_address        city state zipcode  \
# 0        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh    PA   15123
# 1        N  Noodles & Company  3805 Forbes Ave  Pittsburgh    PA   15123
# 2        P       Panera Bread  3800 Forbes Ave  Pittsburgh    PA   15123
#
#    location_id
# 0            1
# 1            2
# 2            3

# %%
['location_id'] + location_info.columns.to_list()[:-1]
# Out:
# ['location_id',
#  'location',
#  'location_name',
#  'street_address',
#  'city',
#  'state',
#  'zipcode']

# %%
location_info = location_info[['location_id'] + location_info.columns.to_list()[:-1]]

# %%
location_info
# Out:
#    location_id location      location_name   street_address        city state  \
# 0            1        D      Dunkin Donuts  3907 Forbes Ave  Pittsburgh    PA
# 1            2        N  Noodles & Company  3805 Forbes Ave  Pittsburgh    PA
# 2            3        P       Panera Bread  3800 Forbes Ave  Pittsburgh    PA
#
#   zipcode
# 0   15123
# 1   15123
# 2   15123

# %% [markdown]
# Save the 3 DataFrames to CSV files.

# %%
shoe_per_day.to_csv('../data/shoe_per_day_table.csv', header=True, index=False)

# %%
shoe_info.to_csv('../data/shoe_info_table.csv', header=True, index=False)

# %%
location_info.to_csv('../data/location_info_table.csv', header=True, index=False)
